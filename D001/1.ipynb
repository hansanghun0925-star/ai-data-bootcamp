# %%
class Order:
    def __init__(self, item, quantity):
        print("객채가 만들어짐")
        self.item = item
        self.quantity = quantity

order1 = Order("한상훈",200)


order1.quantity
# Out:
# 객채가 만들어짐
# 200
